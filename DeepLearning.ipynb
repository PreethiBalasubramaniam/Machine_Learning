# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier, plot_tree
from pandas.plotting import scatter_matrix

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn import  datasets
from sklearn.model_selection import train_test_split

# %%
iris = datasets.load_iris()
x = iris.data
y = iris.target
feature_names = iris.feature_names
target_names = iris.target_names

# %%
iris.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
names = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'species']
iris = pd.read_csv(url, names=names)

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal-length  150 non-null    float64
#  1   sepal-width   150 non-null    float64
#  2   petal-length  150 non-null    float64
#  3   petal-width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
print(iris.head(11))
# Out:
#     sepal-length  sepal-width  petal-length  petal-width      species
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa

# %%
iris.hist()
plt.show()

## Histogram Plots for Each Input Variable for the Iris Dataset

# %%
scatter_matrix(iris)
plt.show()

#Some pairs of Attributes that suggests a high correlation and a predictable relationship.

# %%
iris.plot(kind="scatter", x="sepal-length", y="sepal-width")
# Out:
# <AxesSubplot:xlabel='sepal-length', ylabel='sepal-width'>

# %%
sns.set_style('whitegrid')
sns.FacetGrid(iris, hue = 'species', height = 6).map(plt.scatter, 'sepal-length', 'sepal-width').add_legend()
plt.show()


# Sepal_Lenght & Sepal_Width features works well for Setosa

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.90, random_state=0)
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(x_train,y_train)
y_pred = classifier.predict(X_test)

# When test_size is 0.10, the accuracy level is 100.00 and when test_size is 0.10 accuracy level is 0.10

# %%
print("Accuracy:", classifier.score(x_test,y_test)*100)
# Out:
# Accuracy: 91.11111111111111

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(x_train, y_train)
knn.score(x_test, y_test)

#KNeighbors Classifier score is 0.96
# Out:
# 0.9629629629629629

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
print("Accuracy:", model.score(x_test,y_test)*100)
# Out:
# Accuracy: 94.07407407407408

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.10, random_state=0)
print("Accuracy 1:", model.score(x_test,y_test)*100)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20, random_state=0)
print("Accuracy 2:", model.score(x_test,y_test)*100)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.30, random_state=0)
print("Accuracy 3:", model.score(x_test,y_test)*100)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.40, random_state=0)
print("Accuracy 4:", model.score(x_test,y_test)*100)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.50, random_state=0)
print("Accuracy 5:", model.score(x_test,y_test)*100)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.60, random_state=0)
print("Accuracy 6:", model.score(x_test,y_test)*100)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.70, random_state=0)
print("Accuracy 7:", model.score(x_test,y_test)*100)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.80, random_state=0)
print("Accuracy 8:", model.score(x_test,y_test)*100)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.90, random_state=0)
print("Accuracy 9:", model.score(x_test,y_test)*100)
# Out:
# Accuracy 1: 100.0
# Accuracy 2: 93.33333333333333
# Accuracy 3: 91.11111111111111
# Accuracy 4: 90.0
# Accuracy 5: 92.0
# Accuracy 6: 93.33333333333333
# Accuracy 7: 94.28571428571428
# Accuracy 8: 94.16666666666667
# Accuracy 9: 94.07407407407408

# %%
test_size = 0.20
seed = 7
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = test_size, random_state=seed)
    
print ('Dimensions of X_train: ', X_train.shape)
print ('Dimensions of X_test:  ', X_test.shape)
print ('Dimensions of y_train: ', y_train.shape)
print ('Dimensions of y_test:  ', y_test.shape)
print ('Head of X_train: \n', X_train[:10])
print ('Head of X_test:  \n', X_test[:10])
print ('Head of y_train: ', y_train[:10])
print ('Head of y_test:  ', y_test[:30])
# Out:
# Dimensions of X_train:  (135, 4)
# Dimensions of X_test:   (15, 4)
# Dimensions of y_train:  (120,)
# Dimensions of y_test:   (30,)
# Head of X_train:
#  [[4.8 3.4 1.9 0.2]
#  [7.6 3.  6.6 2.1]
#  [5.  2.  3.5 1. ]
#  [5.8 2.7 5.1 1.9]
#  [5.8 2.6 4.  1.2]
#  [5.7 2.9 4.2 1.3]
#  [5.8 2.7 3.9 1.2]
#  [5.1 3.8 1.9 0.4]
#  [6.1 2.9 4.7 1.4]
#  [5.7 2.8 4.1 1.3]]
# Head of X_test:
#  [[6.6 2.9 4.6 1.3]
#  [4.9 3.1 1.5 0.1]
#  [5.4 3.4 1.5 0.4]
#  [7.2 3.  5.8 1.6]
#  [6.8 3.  5.5 2.1]
#  [7.7 2.6 6.9 2.3]
#  [5.4 3.9 1.3 0.4]
#  [6.3 2.3 4.4 1.3]
#  [5.6 2.5 3.9 1.1]
#  [6.5 3.  5.8 2.2]]
# Head of y_train:  [2 1 0 2 1 0 0 0 0 2]
# Head of y_test:   [2 1 0 1 2 0 1 1 0 1 1 1 0 2 0 1 2 2 0 0 1 2 1 2 2 2 1 1 2 2]
